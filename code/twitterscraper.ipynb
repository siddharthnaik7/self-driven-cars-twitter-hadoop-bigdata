# %%
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; x64; fr; rv:1.9.2.13) Gecko/20101203 Firebird/3.6.13'}

# %%
begin_date = dt.date(2012,1,1)
end_date = dt.date(2019,1,1)

# %%
limit = 1000
lang = 'english'

# %%
tweetsn = query_tweets("nissan self driving car",begindate = begin_date, enddate = end_date, limit = limit, lang = lang )
# Out:
# INFO: queries: ['nissan self driving car since:2012-01-01 until:2012-05-07', 'nissan self driving car since:2012-05-07 until:2012-09-12', 'nissan self driving car since:2012-09-12 until:2013-01-18', 'nissan self driving car since:2013-01-18 until:2013-05-26', 'nissan self driving car since:2013-05-26 until:2013-10-01', 'nissan self driving car since:2013-10-01 until:2014-02-06', 'nissan self driving car since:2014-02-06 until:2014-06-13', 'nissan self driving car since:2014-06-13 until:2014-10-19', 'nissan self driving car since:2014-10-19 until:2015-02-24', 'nissan self driving car since:2015-02-24 until:2015-07-02', 'nissan self driving car since:2015-07-02 until:2015-11-07', 'nissan self driving car since:2015-11-07 until:2016-03-14', 'nissan self driving car since:2016-03-14 until:2016-07-20', 'nissan self driving car since:2016-07-20 until:2016-11-24', 'nissan self driving car since:2016-11-24 until:2017-04-01', 'nissan self driving car since:2017-04-01 until:2017-08-07', 'nissa
# ...

# %%
tweetst = query_tweets("tesla self driving car",begindate = begin_date, enddate = end_date, limit = limit, lang = lang )
# Out:
# INFO: queries: ['tesla self driving car since:2012-01-01 until:2012-05-07', 'tesla self driving car since:2012-05-07 until:2012-09-12', 'tesla self driving car since:2012-09-12 until:2013-01-18', 'tesla self driving car since:2013-01-18 until:2013-05-26', 'tesla self driving car since:2013-05-26 until:2013-10-01', 'tesla self driving car since:2013-10-01 until:2014-02-06', 'tesla self driving car since:2014-02-06 until:2014-06-13', 'tesla self driving car since:2014-06-13 until:2014-10-19', 'tesla self driving car since:2014-10-19 until:2015-02-24', 'tesla self driving car since:2015-02-24 until:2015-07-02', 'tesla self driving car since:2015-07-02 until:2015-11-07', 'tesla self driving car since:2015-11-07 until:2016-03-14', 'tesla self driving car since:2016-03-14 until:2016-07-20', 'tesla self driving car since:2016-07-20 until:2016-11-24', 'tesla self driving car since:2016-11-24 until:2017-04-01', 'tesla self driving car since:2017-04-01 until:2017-08-07', 'tesla self driving ca
# ...

# %%
tweetsf = query_tweets("self driving car",begindate = begin_date, enddate = end_date, limit = 10000, lang = lang )
# Out:
# INFO: queries: ['self driving car since:2012-01-01 until:2012-05-07', 'self driving car since:2012-05-07 until:2012-09-12', 'self driving car since:2012-09-12 until:2013-01-18', 'self driving car since:2013-01-18 until:2013-05-26', 'self driving car since:2013-05-26 until:2013-10-01', 'self driving car since:2013-10-01 until:2014-02-06', 'self driving car since:2014-02-06 until:2014-06-13', 'self driving car since:2014-06-13 until:2014-10-19', 'self driving car since:2014-10-19 until:2015-02-24', 'self driving car since:2015-02-24 until:2015-07-02', 'self driving car since:2015-07-02 until:2015-11-07', 'self driving car since:2015-11-07 until:2016-03-14', 'self driving car since:2016-03-14 until:2016-07-20', 'self driving car since:2016-07-20 until:2016-11-24', 'self driving car since:2016-11-24 until:2017-04-01', 'self driving car since:2017-04-01 until:2017-08-07', 'self driving car since:2017-08-07 until:2017-12-13', 'self driving car since:2017-12-13 until:2018-04-20', 'self driv
# ...

# %%
tweets = query_tweets("audi self driving car",begindate = begin_date, enddate = end_date, limit = limit, lang = lang )
# Out:
# INFO: queries: ['audi self driving car since:2012-01-01 until:2012-05-07', 'audi self driving car since:2012-05-07 until:2012-09-12', 'audi self driving car since:2012-09-12 until:2013-01-18', 'audi self driving car since:2013-01-18 until:2013-05-26', 'audi self driving car since:2013-05-26 until:2013-10-01', 'audi self driving car since:2013-10-01 until:2014-02-06', 'audi self driving car since:2014-02-06 until:2014-06-13', 'audi self driving car since:2014-06-13 until:2014-10-19', 'audi self driving car since:2014-10-19 until:2015-02-24', 'audi self driving car since:2015-02-24 until:2015-07-02', 'audi self driving car since:2015-07-02 until:2015-11-07', 'audi self driving car since:2015-11-07 until:2016-03-14', 'audi self driving car since:2016-03-14 until:2016-07-20', 'audi self driving car since:2016-07-20 until:2016-11-24', 'audi self driving car since:2016-11-24 until:2017-04-01', 'audi self driving car since:2017-04-01 until:2017-08-07', 'audi self driving car since:2017-08-0
# ...

# %%
tweets1 = query_tweets("Mercedes Benz self driving car",begindate = begin_date, enddate = end_date, limit = limit, lang = lang )
# Out:
# INFO: queries: ['Mercedes Benz self driving car since:2012-01-01 until:2012-05-07', 'Mercedes Benz self driving car since:2012-05-07 until:2012-09-12', 'Mercedes Benz self driving car since:2012-09-12 until:2013-01-18', 'Mercedes Benz self driving car since:2013-01-18 until:2013-05-26', 'Mercedes Benz self driving car since:2013-05-26 until:2013-10-01', 'Mercedes Benz self driving car since:2013-10-01 until:2014-02-06', 'Mercedes Benz self driving car since:2014-02-06 until:2014-06-13', 'Mercedes Benz self driving car since:2014-06-13 until:2014-10-19', 'Mercedes Benz self driving car since:2014-10-19 until:2015-02-24', 'Mercedes Benz self driving car since:2015-02-24 until:2015-07-02', 'Mercedes Benz self driving car since:2015-07-02 until:2015-11-07', 'Mercedes Benz self driving car since:2015-11-07 until:2016-03-14', 'Mercedes Benz self driving car since:2016-03-14 until:2016-07-20', 'Mercedes Benz self driving car since:2016-07-20 until:2016-11-24', 'Mercedes Benz self driving ca
# ...

# %%
tweets2 = query_tweets("volvo self driving car",begindate = begin_date, enddate = end_date, limit = limit, lang = lang )
# Out:
# INFO: queries: ['volvo self driving car since:2012-01-01 until:2012-05-07', 'volvo self driving car since:2012-05-07 until:2012-09-12', 'volvo self driving car since:2012-09-12 until:2013-01-18', 'volvo self driving car since:2013-01-18 until:2013-05-26', 'volvo self driving car since:2013-05-26 until:2013-10-01', 'volvo self driving car since:2013-10-01 until:2014-02-06', 'volvo self driving car since:2014-02-06 until:2014-06-13', 'volvo self driving car since:2014-06-13 until:2014-10-19', 'volvo self driving car since:2014-10-19 until:2015-02-24', 'volvo self driving car since:2015-02-24 until:2015-07-02', 'volvo self driving car since:2015-07-02 until:2015-11-07', 'volvo self driving car since:2015-11-07 until:2016-03-14', 'volvo self driving car since:2016-03-14 until:2016-07-20', 'volvo self driving car since:2016-07-20 until:2016-11-24', 'volvo self driving car since:2016-11-24 until:2017-04-01', 'volvo self driving car since:2017-04-01 until:2017-08-07', 'volvo self driving ca
# ...

# %%
tweets3 = query_tweets("toyota self driving car",begindate = begin_date, enddate = end_date, limit = limit, lang = lang )
# Out:
# INFO: queries: ['toyota self driving car since:2012-01-01 until:2012-05-07', 'toyota self driving car since:2012-05-07 until:2012-09-12', 'toyota self driving car since:2012-09-12 until:2013-01-18', 'toyota self driving car since:2013-01-18 until:2013-05-26', 'toyota self driving car since:2013-05-26 until:2013-10-01', 'toyota self driving car since:2013-10-01 until:2014-02-06', 'toyota self driving car since:2014-02-06 until:2014-06-13', 'toyota self driving car since:2014-06-13 until:2014-10-19', 'toyota self driving car since:2014-10-19 until:2015-02-24', 'toyota self driving car since:2015-02-24 until:2015-07-02', 'toyota self driving car since:2015-07-02 until:2015-11-07', 'toyota self driving car since:2015-11-07 until:2016-03-14', 'toyota self driving car since:2016-03-14 until:2016-07-20', 'toyota self driving car since:2016-07-20 until:2016-11-24', 'toyota self driving car since:2016-11-24 until:2017-04-01', 'toyota self driving car since:2017-04-01 until:2017-08-07', 'toyot
# ...

# %%
df1 = pd.DataFrame(t.__dict__ for t in tweets)

# %%
df2 = pd.DataFrame(t.__dict__ for t in tweets1)

# %%
df3 = pd.DataFrame(t.__dict__ for t in tweets2)

# %%
df4 = pd.DataFrame(t.__dict__ for t in tweets3)

# %%
df5 = pd.DataFrame(t.__dict__ for t in tweetst)

# %%
df6 = pd.DataFrame(t.__dict__ for t in tweetsn)

# %%
df7 = pd.DataFrame(t.__dict__ for t in tweetsf)

# %%
df1.drop_duplicates(subset = 'text',inplace = True)

# %%
df2.drop_duplicates(subset = 'text',inplace = True)

# %%
df3.drop_duplicates(subset = 'text',inplace = True)

# %%
df4.drop_duplicates(subset = 'text',inplace = True)

# %%
df5.drop_duplicates(subset = 'text',inplace = True)

# %%
df6.drop_duplicates(subset = 'text',inplace = True)

# %%
df7.drop_duplicates(subset = 'text',inplace = True)

# %%
df=pd.concat([df1, df2, df3, df4, df5, df6])

# %%
df7.shape
# Out:
# (8904, 21)

# %%
df.sort_values('likes', ascending=False)
# Out:
#       has_media                                           hashtags  \
# 302        True                                                 []
# 136       False                                          [driving]
# 285        True                                                 []
# 313       False                                                 []
# 348       False                                  [automation, its]
# 486       False  [Ford, autonomous, google, alphabet, waymo, dr...
# 1038      False  [autonomous, google, alphabet, waymo, driverle...
# 245       False                                      [Japan, news]
# 710        True  [SelfDrivingCars, selfdriving, AutonomousVehic...
# 233        True             [selfdriving, autonomous, vehiclespic]
# 1036      False                                                 []
# 703        True  [USA, American, autonomous_vehicle, Self_drivi...
# 139       False                                  [futuretechhttps]
# ...

# %%
fdf=df[["likes","timestamp","text"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-953a5d61df5a> in <module>
# ----> 1 fdf=df[["likes","timestamp","text"]]
#
# NameError: name 'df' is not defined

# %%
tfdf=df7[["text"]]

# %%
tfdf.head(5)
# Out:
#                                                 text
# 0  i think i passed a self driving car on the way...
# 1  Google comes out with a prototype of their sel...
# 2  Marketing Automation = Self-driving Car. #emai...
# 3  I want to put my telepresence robot in a self-...
# 4  Samsung's Smart Bike has a rearview camera (So...

# %%
fdf.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1aa33befa477> in <module>
# ----> 1 fdf.head(5)
#
# NameError: name 'fdf' is not defined

# %%
fdf.shape
# Out:
# (3752, 3)

# %%
import re
tweet = fdf["text"]
#convert list elements to lower case
tweet_cleaned = [item.lower() for item in tweet]
#remove html links from list 
tweet_cleaned =  [re.sub(r"http\S+", "", item) for item in tweet_cleaned]
#remove special characters left
tweet_cleaned = [re.sub(r"[-()\"Â â € ¦ /;:<>{}`+=~|.!?,]", "", item) for item in tweet_cleaned]
#convert to dataframe
#tweet_cleaned = pd.DataFrame(np.array(tweet_cleaned).reshape(-1))

# %%
import re
tweet1 = tfdf["text"]
#convert list elements to lower case
tweet_cleaned = [item.lower() for item in tweet1]
#remove html links from list 
tweet_cleaned =  [re.sub(r"http\S+", "", item) for item in tweet_cleaned]
#remove special characters left
tweet_cleaned1 = [re.sub(r"[-()\"Â â € ¦ /;:<>{}`+=~|.!?,]", "", item) for item in tweet_cleaned]
#convert to dataframe
#tweet_cleaned = pd.DataFrame(np.array(tweet_cleaned).reshape(-1))

# %%
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.util import ngrams
from nltk.util import bigrams
from nltk.collocations import *
from mpl_toolkits.mplot3d import Axes3D
from collections import defaultdict
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from PIL import Image
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vivek\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
summary = fdf['text']
#Covert list elements to lower case and spit 
summary = summary.apply(lambda x: " ".join(x.lower() for x in x.split()))
summary = summary.str.replace('[^\w\s]','')
stop = set(stopwords.words('english'))
summary = summary.apply(lambda x: " ".join(x for x in x.split() if x not in stop))
summary.head(10)
freq = pd.Series(' '.join(summary).split()).value_counts()[:100]
freq
# Out:
# car               4087
# selfdriving       3141
# driving            919
# self               840
# tesla              749
# toyota             711
# audi               623
# volvo              563
# google             527
# nissan             517
# mercedesbenz       475
# via                407
# new                258
# first              205
# technology         186
# tech               181
# video              166
# ford               164
# future             159
# cars               159
# uber               151
# bmw                143
# autonomous         139
# volvos             139
# mercedes           131
# selfdrivingcar     129
# audis              125
# lidarmonkey        123
# test               122
# nissans            122
#                   ...
# mercedesbenzs       64
# silicon             63
# year                63
# valley              63
# bosch               61
# accident            60
# california          60
# think               59
# crash               59
# ...

# %%
fdf["Tweet"] = tweet_cleaned
# Out:
# C:\Users\vivek\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
fdf.head(5)
# Out:
#    likes           timestamp  \
# 0      0 2012-09-03 16:34:28
# 1      0 2012-09-01 17:09:18
# 2      1 2012-08-30 07:03:30
# 3      0 2012-08-27 01:52:31
# 4      0 2012-08-21 13:45:02
#
#                                                 text  \
# 0  Check it! Urban future self-driving car concep...
# 1  Self Driving Car Tops 120mph http://goo.gl/VtP...
# 2  Audi's Autonomous Audi TTS reached 200 km/h wi...
# 3  Self driving car, pfft. How about a self drivi...
# 4  #Stanford's Self Driving Car Tops 120mph On Ra...
#
#                                                Tweet
# 0   checkiturbanfutureselfdrivingcarconceptfromaudi
# 1                 selfdrivingcartops120mph #audi_tts
# 2  audi'sautonomousaudittsreached200kmhwithoutadr...
# 3  selfdrivingcarpffthowaboutaselfdrivingracecara...
# 4  #stanford'sselfdrivingcartops120mphonracetrack...

# %%
fdf=fdf[["likes","timestamp","Tweet"]]

# %%
fdf.isnull().sum()
# Out:
# likes        0
# timestamp    0
# Tweet        0
# dtype: int64

# %%
fdf.to_csv(r'C:\Users\vivek\Desktop\Courses\BAN 632 - BD\twitterdata.csv')

# %%
tfdf["Tweet1"]=tweet_cleaned1
# Out:
# C:\Users\vivek\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tfdf=tfdf[["Tweet1"]]

# %%
tfdf.shape
# Out:
# (8904, 1)

# %%
tfdf.to_csv(r'C:\Users\vivek\Desktop\Courses\BAN 632 - BD\twitterall.csv')

# %%
def plot_wordcloud(text, mask=None, max_words=200, max_font_size=100, figure_size=(12,8), 
                   title = None, title_size=20, image_color=False):
    stopwords = set(STOPWORDS)
    #define additional stop words that are not contained in the dictionary
    more_stopwords = {'one', 'br', 'Po', 'th', 'sayi', 'fo', 'Unknown'}
    stopwords = stopwords.union(more_stopwords)
    #Generate the word cloud
    wordcloud = WordCloud(background_color='black',
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size, 
                    random_state = 42,
                    width=800, 
                    height=400,
                          
                    mask = mask)
    wordcloud.generate(str(text))
    #set the plot parameters
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = colors;
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'black', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout() 
    plt.savefig('4.png', dpi=720)

# %%
tfdf=df7[["text"]]
summaryX = tfdf['text']
#Covert list elements to lower case and spit 
summary = summary.apply(lambda x: " ".join(x.lower() for x in x.split()))
summary = summary.str.replace('[^\w\s]','')
stop = set(stopwords.words('english'))
summary = summary.apply(lambda x: " ".join(x for x in x.split() if x not in stop))
summary.head(10)
freq = pd.Series(' '.join(summary).split()).value_counts()[:20]
freq.plot(kind='bar', title='Top 20 Unigrams for Self Driving Car Tweets')

# %%
plot_wordcloud(summaryX, title="Word Cloud of Self Driving Car")
